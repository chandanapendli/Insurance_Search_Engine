# %%
import pandas as pd
import numpy as np
import nltk
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import SnowballStemmer
# Download NLTK data
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data = pd.read_csv('/content/Insurance_FAQs.csv')

# %%
data
# Out:
#                                               Question  \
# 0    What do you mean by exclusions under the Accid...
# 1    Can I include my spouse in this the Accidental...
# 2                                How do I make a claim
# 3    When does my Revive Policy for Personal Accide...
# 4    What plans are available under  the Revive Pol...
# ..                                                 ...
# 464  Where can I get the list of hospitals extendin...
# 465  For how many days can the Travel Insurance pol...
# 466  What are the eligibility criteria for a Travel...
# 467  Who do I contact for a claim on the Travel Ins...
# 468  Is emergency financial assistance provided und...
#
#                                                 Answer      Class
# 0    Exclusions are situations or conditions where ...  insurance
# 1    Yes, you can include your spouse and up to 2 c...  insurance
# 2    You can make a claim by calling our toll-free ...  insurance
# 3    It will commence within 15 days from the date ...  insurance
# 4    HDFC ERGO offers a wide range of sums insured ...  insurance
# ..                                                 ...        ...
# 464  There is no standard list of hospitals. The in...  insurance
# 465  The policy may be extended for a maximum of 18...  insurance
# 466  Our Travel Insurance policy is available to pe...  insurance
# 467  In the event of a covered emergency and to reg...  insurance
# 468  A financial emergency is a situation where the...  insurance
#
# [469 rows x 3 columns]

# %%
stemmer = SnowballStemmer(language='english')
def preprocess(text):
    tokens = nltk.word_tokenize(text.lower())
    stems = [stemmer.stem(token) for token in tokens]
    return ' '.join(stems)

data['Question'] = data['Question'].apply(preprocess)

# %%
tfidf_vectorizer = TfidfVectorizer()
X = tfidf_vectorizer.fit_transform(data['Question'])

# %%
# Train a simple chatbot using cosine similarity
def search_engine(user_input):
    user_input = preprocess(user_input)
    user_input_vector = tfidf_vectorizer.transform([user_input])

    similarities = cosine_similarity(X, user_input_vector)
    # Threshold to consider a response related
    threshold = 0.2
    related_indices = np.argwhere(similarities > threshold).flatten()
    if len(related_indices) == 0:
        return "I'm sorry, I couldn't find relevant information for your query."
    else:
        # Find the index of the most similar question
        most_similar_index = np.argmax(similarities)
        return data['Answer'].iloc[most_similar_index]

# %%
# Main function to interact with the chatbot
def main():
    while True:
        user_input = input("You: ")
        if user_input.lower() == 'q':
            break
        else:
            response = search_engine(user_input)
            print("Search:", response)

if __name__ == "__main__":
    main()
# Out:
# You: health insurance
# Search: Health insurance is a type of insurance coverage that covers the cost of an insured individual's medical and surgical expenses.
# You: travel insurance
# Search: Travel Insurance is not mandatory in India. However, it is mandatory in the UK and others countries including Austria, Greece, Portugal, Spain, France, Germany, Belgium, Luxembourg and the Netherlands. However, for a safe and peaceful trip, we recommend that you have a travel insurance policy no matter which country you are travelling to.
# You: abc
# Search: I'm sorry, I couldn't find relevant information for your query.
# You: q

# %%
    # Save the trained components
    with open('Search_Engine_trained_components.pkl', 'wb') as f:
        pickle.dump((tfidf_vectorizer, data), f)
    print("Trained components saved successfully.")
# Out:
# Trained components saved successfully.
